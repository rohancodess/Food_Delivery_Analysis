# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("food_delivery_data.csv")

# %%
df
# Out:
#        Unnamed: 0      ID Delivery_person_ID  Delivery_person_Age  \
# 0               0  0xd224      DEHRES11DEL03                 21.0
# 1               1  0x30d6   RANCHIRES18DEL02                 23.0
# 2               2  0x8f18     INDORES18DEL02                 39.0
# 3               3  0xdbd2      KOCRES02DEL03                 23.0
# 4               4  0x129b      VADRES08DEL01                 31.0
# ...           ...     ...                ...                  ...
# 37226       37226  0x799d     INDORES14DEL02                 39.0
# 37227       37227  0xb350      MUMRES20DEL02                 20.0
# 37228       37228  0x6a92      VADRES01DEL01                 31.0
# 37229       37229  0x2484      VADRES05DEL01                 32.0
# 37230       37230  0x65a1      JAPRES16DEL03                 24.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9             0.000000              0.000000
# ...

# %% [markdown]
# #all column description

# %% [markdown]
# '''- *ID*: String (object). Unique identifier for each delivery record, formatted as a hexadecimal string (e.g., 0xd224).
# - *Delivery_person_ID*: String (object). Unique identifier for the delivery person, combining city code and a specific ID (e.g., DEHRES11DEL03).
# - *Delivery_person_Age*: Float. Age of the delivery person, ranging from 20 to 39 years, with some missing values.
# - *Delivery_person_Ratings*: Float. Rating of the delivery person, ranging from 3.2 to 5.0, with some missing values.
# - *Restaurant_latitude*: Float. Latitude coordinate of the restaurant, with some entries as 0.0 indicating missing or invalid data.
# - *Restaurant_longitude*: Float. Longitude coordinate of the restaurant, with some entries as 0.0 indicating missing or invalid data.
# - *Delivery_location_latitude*: Float. Latitude coordinate of the delivery location, with small increments from restaurant latitude.
# - *Delivery_location_longitude*: Float. Longitude coordinate of the delivery location, with small increments from restaurant longitude.
# - *Order_Date*: String (object). Date of the order in DD-MM-YYYY format (e.g., 15-02-2022).
# - *Time_Orderd*: String (object). Time when the order was placed in HH:MM:SS format (e.g., 21:35:00), with some missing values.
# - *Time_Order_picked*: String (object). Time when the order was picked up in HH:MM:SS format (e.g., 21:45:00).
# - *Weatherconditions*: String (object). Weather condition during delivery, with categories like Sunny, Cloudy, Fog, Windy, Stormy, Sandstorms.
# - *Road_traffic_density*: String (object). Traffic density during delivery, categorized as Low, Medium, High, or Jam.
# - *Vehicle_condition*: Float. Condition of the delivery vehicle, ranging from 0.0 to 2.0, representing poor to good condition.
# - *Type_of_order*: String (object). Type of food order, with categories like Buffet, Drinks, Meal, Snack.
# - *Type_of_vehicle*: String (object). Type of vehicle used for delivery, with categories like motorcycle, scooter, electric_scooter.
# - *multiple_deliveries*: Float. Number of deliveries in a single trip, ranging from 0.0 to 2.0, with some missing values.
# - *Festival*: String (object). Indicates if the delivery occurred during a festival, with values Yes or No.
# - *City*: String (object). Type of city where delivery occurred, with categories Urban, Metropolitian, Semi-Urban.
# - *Time_taken(min)*: Float. Time taken for delivery in minutes, ranging from 10.0 to 54.0.'''

# %%
df.tail()
# Out:
#        Unnamed: 0      ID Delivery_person_ID  Delivery_person_Age  \
# 37226       37226  0x799d     INDORES14DEL02                 39.0
# 37227       37227  0xb350      MUMRES20DEL02                 20.0
# 37228       37228  0x6a92      VADRES01DEL01                 31.0
# 37229       37229  0x2484      VADRES05DEL01                 32.0
# 37230       37230  0x65a1      JAPRES16DEL03                 24.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 37226                      4.4            22.761593             75.886362
# 37227                      4.9            19.103249             72.846749
# 37228                      4.9            22.307898             73.167788
# 37229                      4.9            22.310526             73.170937
# 37230                      4.8            26.849596             75.800512
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37231 entries, 0 to 37230
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   37231 non-null  int64
#  1   ID                           37231 non-null  object
#  2   Delivery_person_ID           37231 non-null  object
#  3   Delivery_person_Age          37231 non-null  float64
#  4   Delivery_person_Ratings      37231 non-null  float64
#  5   Restaurant_latitude          37231 non-null  float64
#  6   Restaurant_longitude         37231 non-null  float64
#  7   Delivery_location_latitude   37231 non-null  float64
#  8   Delivery_location_longitude  37231 non-null  float64
#  9   Order_Date                   37231 non-null  object
#  10  Time_Orderd                  37231 non-null  object
#  11  Time_Order_picked            37231 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Delivery_person_Age  Delivery_person_Ratings  \
# count  37231.000000         37231.000000             37231.000000
# mean   18615.000000            29.633827                 4.632486
# std    10747.808273             5.762729                 0.317384
# min        0.000000            20.000000                 2.500000
# 25%     9307.500000            25.000000                 4.500000
# 50%    18615.000000            30.000000                 4.700000
# 75%    27922.500000            35.000000                 4.900000
# max    37230.000000            39.000000                 5.000000
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         37231.000000          37231.000000                37231.000000
# mean             17.259885             70.792358                   17.481620
# std               7.692387             21.086972                    7.329362
# ...

# %%
 #issue
 #Unamed:0         drop the column
 #ID              -convert hexadiecmle to integer
 #age             -convert float to int
 #order_date      - convert to date from object type
 #vehicle_condition  - convert numericle to categoricle
 #multiple_deliveries  -convetr dtype to int32

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df['Delivery_person_Age']=df['Delivery_person_Age'].astype('int32')
df['Delivery_person_Age'].dtype
# Out:
# dtype('int32')

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3224\1882151666.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37231 entries, 0 to 37230
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           37231 non-null  object
#  1   Delivery_person_ID           37231 non-null  object
#  2   Delivery_person_Age          37231 non-null  int32
#  3   Delivery_person_Ratings      37231 non-null  float64
#  4   Restaurant_latitude          37231 non-null  float64
#  5   Restaurant_longitude         37231 non-null  float64
#  6   Delivery_location_latitude   37231 non-null  float64
#  7   Delivery_location_longitude  37231 non-null  float64
#  8   Order_Date                   37231 non-null  datetime64[ns]
#  9   Time_Orderd                  37231 non-null  object
#  10  Time_Order_picked            37231 non-null  object
#  11  Weatherconditions            37231 non-null  object
# ...

# %%
df['multiple_deliveries']=df['multiple_deliveries'].astype('int32')
df['multiple_deliveries'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37231 entries, 0 to 37230
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           37231 non-null  object
#  1   Delivery_person_ID           37231 non-null  object
#  2   Delivery_person_Age          37231 non-null  int32
#  3   Delivery_person_Ratings      37231 non-null  float64
#  4   Restaurant_latitude          37231 non-null  float64
#  5   Restaurant_longitude         37231 non-null  float64
#  6   Delivery_location_latitude   37231 non-null  float64
#  7   Delivery_location_longitude  37231 non-null  float64
#  8   Order_Date                   37231 non-null  datetime64[ns]
#  9   Time_Orderd                  37231 non-null  object
#  10  Time_Order_picked            37231 non-null  object
#  11  Weatherconditions            37231 non-null  object
# ...

# %%
df = df.drop(df[(df['Restaurant_latitude'] == 0) & (df['Restaurant_longitude'] == 0)].index)
#so we drop raws cause longitude and latitude 0,0 don't make sense

# %%
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x30d6   RANCHIRES18DEL02                   23
# 2      0x8f18     INDORES18DEL02                   39
# 3      0xdbd2      KOCRES02DEL03                   23
# 5      0x2185     PUNERES12DEL01                   34
# 6      0x606c    COIMBRES14DEL02                   20
# ...       ...                ...                  ...
# 37226  0x799d     INDORES14DEL02                   39
# 37227  0xb350      MUMRES20DEL02                   20
# 37228  0x6a92      VADRES01DEL01                   31
# 37229  0x2484      VADRES05DEL01                   32
# 37230  0x65a1      JAPRES16DEL03                   24
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.8            23.351489             85.324253
# 2                          4.6            22.753839             75.897429
# 3                          4.5            10.028047             76.310019
# ...

# %%
#eda

# %%
df['Vehicle_condition_name']=df['Vehicle_condition'].map({0.0:'poor',1.0:'nutral',2.0:'good'})

# %%
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x30d6   RANCHIRES18DEL02                   23
# 2      0x8f18     INDORES18DEL02                   39
# 3      0xdbd2      KOCRES02DEL03                   23
# 5      0x2185     PUNERES12DEL01                   34
# 6      0x606c    COIMBRES14DEL02                   20
# ...       ...                ...                  ...
# 37226  0x799d     INDORES14DEL02                   39
# 37227  0xb350      MUMRES20DEL02                   20
# 37228  0x6a92      VADRES01DEL01                   31
# 37229  0x2484      VADRES05DEL01                   32
# 37230  0x65a1      JAPRES16DEL03                   24
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.8            23.351489             85.324253
# 2                          4.6            22.753839             75.897429
# 3                          4.5            10.028047             76.310019
# ...

# %%
#univeriate analysis on Numericle column

# %%
df['Delivery_person_Age'].describe()
# Out:
# count    34268.000000
# mean        29.635374
# std          5.760553
# min         20.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         39.000000
# Name: Delivery_person_Age, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Delivery_person_Age'], bins=5, edgecolor='black')
plt.title('Histogram of age')
plt.xlabel('age')
plt.show()

plt.boxplot(df['Delivery_person_Age'])
plt.title('Boxplot of Age')
plt.ylabel('Value')
plt.show()

# %%
df['Delivery_person_Age'].skew()
# Out:
# -0.03380856381255609

# %% [markdown]
# The age data is approximately normally distributed, with a slight left skew.
# This means most values are centered, with a few younger ages pulling the distribution slightly left.

# %%
plt.hist(df['Time_taken(min)'], bins=5, edgecolor='black')
plt.title('Histogram of delievery Time_taken(min)')
plt.xlabel('Time_taken(min)')
plt.show()

plt.boxplot(df['Time_taken(min)'])
plt.title('Boxplot of delievery Time_taken(min)')
plt.ylabel('Value')
plt.show()

# %%
df['Time_taken(min)'].skew()
# Out:
# 0.4740316061139166

# %% [markdown]
# #Delivery times are generally consistent, but there are some delay that cause longer delivery times in a few cases.

# %%
plt.hist(df['Delivery_person_Ratings'],bins=5, edgecolor='black')
plt.title('Histogram of Delivery_person_Ratings')
plt.xlabel('Delivery_person_Ratings')
plt.show()

plt.boxplot(df['Delivery_person_Ratings'])
plt.title('Boxplot of Delivery_person_Ratings')
plt.ylabel('Value')
plt.show()

# %%
df['Delivery_person_Ratings'].skew()
# Out:
# -1.7820013417680416

# %% [markdown]
# Most customers give high ratings to delivery persons, but a few very low ratings (perhaps due to poor service or rare issues) pull the average down, causing the strong negative skew.

# %%
#univariate analysis on categoricle column

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 1  0x30d6   RANCHIRES18DEL02                   23                      4.8
# 2  0x8f18     INDORES18DEL02                   39                      4.6
# 3  0xdbd2      KOCRES02DEL03                   23                      4.5
# 5  0x2185     PUNERES12DEL01                   34                      4.9
# 6  0x606c    COIMBRES14DEL02                   20                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 1            23.351489             85.324253                   23.371489
# 2            22.753839             75.897429                   22.833838
# 3            10.028047             76.310019                   10.088047
# 5            18.520016             73.830547                   18.630016
# 6            11.003681             76.975525                   11.053681
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)',
#        'Vehicle_condition_name'],
#       dtype='object')

# %%
counts = df['Weatherconditions'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in Weatherconditions')
plt.ylabel('')  # to hidw lable
plt.show()
# Out:
# Weatherconditions
# Fog           5884
# Stormy        5787
# Cloudy        5739
# Sandstorms    5677
# Windy         5656
# Sunny         5525
# Name: count, dtype: int64

# %%
counts = df['Road_traffic_density'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in Road_traffic_density')
plt.ylabel('') 
plt.show()
# Out:
# Road_traffic_density
# Low       11618
# Jam       10891
# Medium     8407
# High       3352
# Name: count, dtype: int64

# %% [markdown]
# #most of our trafic density was low or jam , then medium and then high

# %%
counts = df['Type_of_order'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in Order_type')
plt.ylabel('') 
plt.show()
# Out:
# Type_of_order
# Meal      8625
# Snack     8612
# Drinks    8545
# Buffet    8486
# Name: count, dtype: int64

# %% [markdown]
# this almost show eually distibution

# %%
counts = df['Type_of_vehicle'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in Vehicle_type')
plt.ylabel('') 
plt.show()
# Out:
# Type_of_vehicle
# motorcycle          20157
# scooter             11375
# electric_scooter     2736
# Name: count, dtype: int64

# %% [markdown]
# mostly people use motorcycle for deleviery where few use electic_scooter

# %%
counts = df['Festival'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in Festival')
plt.ylabel('') 
plt.show()
# Out:
# Festival
# No     33569
# Yes      699
# Name: count, dtype: int64

# %% [markdown]
# #as per our dataset most of dileveries are done without festivle

# %%
counts = df['City'].value_counts()
print(counts)
plt.figure()
counts.plot.pie(autopct='%1.1f%%',cmap='tab20')
plt.title('Category Distribution in city')
plt.ylabel('') 
plt.show()
# Out:
# City
# Metropolitian    26400
# Urban             7748
# Semi-Urban         120
# Name: count, dtype: int64

# %% [markdown]
# our major deliveries are done in metroplotian area

# %% [markdown]
# bivariate analysis

# %%
#for numericle to numericle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)',
#        'Vehicle_condition_name'],
#       dtype='object')

# %%
sns.scatterplot(x='Restaurant_latitude', y='Delivery_location_latitude', data=df)
plt.title('')
plt.xlabel('Restaurant_latitude')
plt.ylabel('Delivery_location_latitude')
plt.show()

# %% [markdown]
# now understand it's iterative process i have found that we have to remove resturants longitude and latitude points were data are 0
# cause 0,0 points indicates middle part of african sea

# %%
sns.scatterplot(x='Delivery_person_Ratings', y='Delivery_person_Age', data=df)
plt.title('')
plt.xlabel('Delivery_person_Ratings')
plt.ylabel('Delivery_person_Age')
plt.show()

# %% [markdown]
# #below 3 delievery person rating are mostly younger people that age vary from 20-30

# %%
#numericle-categoricle

# %%
sns.barplot(x='multiple_deliveries',y='Delivery_person_Age',data=df)
plt.title('')
plt.xlabel('multiple_deliveries')
plt.ylabel('Delivery_person_Age')
plt.ylim(20, df['Delivery_person_Age'].max())
plt.show()

# %% [markdown]
# #age group 30-33 are mostly handle multiple deleveries 2-3 while comare to other

# %%
sns.violinplot(x='Road_traffic_density',y='Time_taken(min)',data=df)
plt.title('')
plt.xlabel('Road_traffic_density')
plt.ylim(df['Time_taken(min)'].min(), df['Time_taken(min)'].max())
plt.show()

# %%
sns.violinplot(x='Weatherconditions',y='Time_taken(min)',data=df)
plt.title('')
plt.xlabel('Weatherconditions')
plt.ylim(df['Time_taken(min)'].min(), df['Time_taken(min)'].max())
plt.show()

# %%
#categoricle-categoricle

# %%
pip install geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.distance import geodesic

df['distance_km'] = df.apply(
    lambda row: geodesic(
        (row['Restaurant_latitude'], row['Restaurant_longitude']),
        (row['Delivery_location_latitude'], row['Delivery_location_longitude'])
    ).kilometers,
    axis=1
)

# %%
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x30d6   RANCHIRES18DEL02                   23
# 2      0x8f18     INDORES18DEL02                   39
# 3      0xdbd2      KOCRES02DEL03                   23
# 5      0x2185     PUNERES12DEL01                   34
# 6      0x606c    COIMBRES14DEL02                   20
# ...       ...                ...                  ...
# 37226  0x799d     INDORES14DEL02                   39
# 37227  0xb350      MUMRES20DEL02                   20
# 37228  0x6a92      VADRES01DEL01                   31
# 37229  0x2484      VADRES05DEL01                   32
# 37230  0x65a1      JAPRES16DEL03                   24
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.8            23.351489             85.324253
# 2                          4.6            22.753839             75.897429
# 3                          4.5            10.028047             76.310019
# ...

# %%
plt.hist(df['distance_km'], bins=5, edgecolor='black')
plt.title('Histogram of delievery Time_taken(min)')
plt.xlabel('Time_taken(min)')
plt.show()

plt.boxplot(df['distance_km'])
plt.title('Boxplot of delievery Time_taken(min)')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# #from above graph we can see we get outliers so we have to remove it

# %%
df['distance_km'].describe()
# Out:
# count    34268.000000
# mean        28.711428
# std        314.382002
# min          1.463837
# 25%          4.648998
# 50%          9.204085
# 75%         13.661188
# max       6852.617172
# Name: distance_km, dtype: float64

# %%
len(df[df['distance_km']>30])
# Out:
# 134

# %%
df = df.drop(df[df['distance_km'] > 30].index)

# %%
df['distance_km'].max()
# Out:
# 20.94290627698551

# %%
plt.hist(df['distance_km'], bins=5, edgecolor='black')
plt.title('Histogram of delievery Time_taken(min)')
plt.xlabel('Time_taken(min)')
plt.show()

plt.boxplot(df['distance_km'])
plt.title('Boxplot of delievery Time_taken(min)')
plt.ylabel('Value')
plt.show()

# %%
df.to_excel('food_delivery_data.xlsx',index=False)

# %% [markdown]
# Insights

# %% [markdown]
# - Delivery times increase significantly during high traffic density and adverse weather conditions like fog or cloudy.
#
# - Surprisingly not a adult(20-27 age) but a younger delivery people(29-36 age) with better vehicle conditions tend to deliver faster and receive higher    ratings.
#
# - Metropolitan city area have more deliveries compare to urban and semi-urban but at urban areas there is less dilivery time compare to metropoliton and   semi-urban.
#
# - According to calculation Meals and snacks as food orders are the most frequently and more ordered food types among total orders
